# %% [markdown]
# ### Load Data: California_housing_dataset

# %%
url = "https://raw.githubusercontent.com/nijiati-abulizi/BitSize_ML/main/end_to_end_ml/data/housing.csv"

# %%
# brew install tree
# before
# !tree ~/Projects/BitSize_ML/end_to_end_ml
# Out:
# /Users/nejat/Projects/BitSize_ML/end_to_end_ml
# ├── data
# ├── images
# │   └── ENV checking.png
# ├── models
# └── notebooks
#     ├── 1_setup.ipynb
#     └── 2_fetch_data.ipynb
#
# 5 directories, 3 files

# %%
from pathlib import Path
import urllib.request
import pandas as pd

# %%
data_path = Path.cwd().parent / "data" / "housing.csv"

if not data_path.exists():
    urllib.request.urlretrieve(url, data_path)
else:
    print("File exists.")

housing = pd.read_csv(data_path)
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#after
# !tree ~/Projects/BitSize_ML/end_to_end_ml
# Out:
# /Users/nejat/Projects/BitSize_ML/end_to_end_ml
# ├── data
# │   └── housing.csv
# ├── images
# │   └── ENV checking.png
# ├── models
# └── notebooks
#     ├── 1_setup.ipynb
#     └── 2_fetch_data.ipynb
#
# 5 directories, 4 files
